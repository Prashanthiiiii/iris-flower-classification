# %%
#importing the libraries
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report
from sklearn.linear_model  import LinearRegression

# %%
#importing the dataset
df = pd.read_csv(r"C:\Users\PRASHANTHI\Downloads\Iris.csv")

# %%
df.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
df.tail()
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 145  Iris-virginica
# 146  Iris-virginica
# 147  Iris-virginica
# 148  Iris-virginica
# 149  Iris-virginica

# %%
df.shape
# Out:
# (150, 6)

# %%
x=df['SepalLengthCm']
y=df['PetalLengthCm']
plt.figure(figsize=(4,4))
plt.scatter(x,y,color='red',edgecolor='black')
plt.xlabel('sepalLength',weight='bold')
plt.ylabel('petalLength',weight='bold')
plt.suptitle('sepalLength vs petalLength',weight='bold')
# Out:
# Text(0.5, 0.98, 'sepalLength vs petalLength')

# %%
df['Species'].unique()
# Out:
# array(['Iris-setosa', 'Iris-versicolor', 'Iris-virginica'], dtype=object)

# %%
colors = ['red','purple','cyan']
species = ['Iris-setosa','Iris-versicolor','Iris-virginica']

# %%
df.columns
# Out:
# Index(['Id', 'SepalLengthCm', 'SepalWidthCm', 'PetalLengthCm', 'PetalWidthCm',
#        'Species'],
#       dtype='object')

# %%
df.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
df.loc[3,'PetalLengthCm']
# Out:
# 1.5

# %%
df.loc[0:10,['SepalLengthCm','PetalLengthCm']]
# Out:
#     SepalLengthCm  PetalLengthCm
# 0             5.1            1.4
# 1             4.9            1.4
# 2             4.7            1.3
# 3             4.6            1.5
# 4             5.0            1.4
# 5             5.4            1.7
# 6             4.6            1.4
# 7             5.0            1.5
# 8             4.4            1.4
# 9             4.9            1.5
# 10            5.4            1.5

# %%
plt.figure(figsize=(5,5))
plt.grid(color='black')
for i in range(3):
     y = df[df['Species']==species[i]]
     plt.scatter(y['SepalLengthCm'],y['PetalLengthCm'],color=colors[i],edgecolor='black')
     plt.xlabel('SepalLength',weight='bold')
     plt.ylabel('PetalLength',weight='bold')

# %%
plt.figure(figsize=(4,4))
for i in range(3):
     y = df[df['Species']==species[i]]
     plt.scatter(y['SepalWidthCm'],y['PetalWidthCm'],color=colors[i],edgecolor='black')
     plt.xlabel('SepalWidth',weight='bold')
     plt.ylabel('PetalWidth',weight='bold')

# %%
x2=df['PetalLengthCm']
y2=df['PetalWidthCm']
plt.figure(figsize=(4,4))
plt.scatter(x2,y2,color='blue',edgecolor='red')
plt.suptitle('petalLength vs PetalWidth',style='italic',weight='bold')
plt.xlabel('PetalLengthCm',weight='bold')
plt.ylabel('PetalWidthCm',weight='bold')
# Out:
# Text(0, 0.5, 'PetalWidthCm')

# %%
df.isnull().sum()
# Out:
# Id               0
# SepalLengthCm    0
# SepalWidthCm     0
# PetalLengthCm    0
# PetalWidthCm     0
# Species          0
# dtype: int64

# %%
df.columns
# Out:
# Index(['Id', 'SepalLengthCm', 'SepalWidthCm', 'PetalLengthCm', 'PetalWidthCm',
#        'Species'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 50 entries, 0 to 49
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             50 non-null     int64
#  1   SepalLengthCm  50 non-null     float64
#  2   SepalWidthCm   50 non-null     float64
#  3   PetalLengthCm  50 non-null     float64
#  4   PetalWidthCm   50 non-null     float64
#  5   Species        50 non-null     object
# dtypes: float64(4), int64(1), object(1)
# memory usage: 2.7+ KB

# %%
df.describe()
# Out:
#              Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# count  50.00000       50.00000     50.000000      50.000000      50.00000
# mean   25.50000        5.00600      3.418000       1.464000       0.24400
# std    14.57738        0.35249      0.381024       0.173511       0.10721
# min     1.00000        4.30000      2.300000       1.000000       0.10000
# 25%    13.25000        4.80000      3.125000       1.400000       0.20000
# 50%    25.50000        5.00000      3.400000       1.500000       0.20000
# 75%    37.75000        5.20000      3.675000       1.575000       0.30000
# max    50.00000        5.80000      4.400000       1.900000       0.60000

# %%
df.describe().T
# Out:
#                count    mean        std  min     25%   50%     75%   max
# Id              50.0  25.500  14.577380  1.0  13.250  25.5  37.750  50.0
# SepalLengthCm   50.0   5.006   0.352490  4.3   4.800   5.0   5.200   5.8
# SepalWidthCm    50.0   3.418   0.381024  2.3   3.125   3.4   3.675   4.4
# PetalLengthCm   50.0   1.464   0.173511  1.0   1.400   1.5   1.575   1.9
# PetalWidthCm    50.0   0.244   0.107210  0.1   0.200   0.2   0.300   0.6

# %%
df[['SepalLengthCm','SepalWidthCm','PetalLengthCm','PetalWidthCm']].agg({'SepalLengthCm':['min','max','count'],
                                                                          'SepalWidthCm':['std','min','nunique'],
                                                                         'PetalLengthCm':['sum','mean']})
# Out:
#          SepalLengthCm  SepalWidthCm  PetalLengthCm
# min                4.3      2.300000            NaN
# max                5.8           NaN            NaN
# count             50.0           NaN            NaN
# std                NaN      0.381024            NaN
# nunique            NaN     16.000000            NaN
# sum                NaN           NaN         73.200
# mean               NaN           NaN          1.464

# %%
df.hist(figsize=(7,7))
# Out:
# array([[<Axes: title={'center': 'Id'}>,
#         <Axes: title={'center': 'SepalLengthCm'}>],
#        [<Axes: title={'center': 'SepalWidthCm'}>,
#         <Axes: title={'center': 'PetalLengthCm'}>],
#        [<Axes: title={'center': 'PetalWidthCm'}>, <Axes: >]], dtype=object)

# %%
plt.figure(figsize=(5,5))
sns.heatmap(df.corr(),annot=True,cmap='plasma')
sns.title
# Out:
# C:\Users\SRI LAVANYA\AppData\Local\Temp\ipykernel_15816\3974704784.py:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(df.corr(),annot=True,cmap='plasma')
# <Axes: >

# %%
sns.pairplot(df,hue='Species')

# %%
df.shape
# Out:
# (150, 6)

# %%
from sklearn.preprocessing import LabelEncoder
encoder = LabelEncoder()

# %%
df['Species'] = encoder.fit_transform(df['Species'])

# %%
df.columns
# Out:
# Index(['Id', 'SepalLengthCm', 'SepalWidthCm', 'PetalLengthCm', 'PetalWidthCm',
#        'Species'],
#       dtype='object')

# %%
x = df.drop(columns=['Species'])
y = df['Species']

# %%
x_train , x_test ,y_train, y_test = train_test_split(x,y,test_size=0.3,random_state=23)

# %%
model = LinearRegression()

# %%
model.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
model.score(x_test,y_test)
# Out:
# 0.9720154183119429
